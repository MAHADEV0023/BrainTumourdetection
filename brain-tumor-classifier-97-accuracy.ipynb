# %% [markdown]
# ##   <font color='magenta'>Brain Tumor Detection</font>

# %% [markdown]
# ##   <font color='Aquamarine'>Import libraries</font>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import cv2
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tqdm import tqdm
import os
from sklearn.utils import shuffle
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import EfficientNetB2,EfficientNetB3,EfficientNetB5,InceptionResNetV2#,EfficientNetV2S
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping,ModelCheckpoint
import keras
import sklearn.metrics as metrics
from sklearn.metrics import classification_report
#from pretty_confusion_matrix import pp_matrix
#confusion_matrix = metrics.confusion_matrix(y_true=y_test_labels, y_pred=pred_labels)  # shape=(12, 12)
from sklearn.metrics import confusion_matrix

# %%
#!pip install tf-nightly
#!pip install keras_efficientnets
#!pip install pretty-confusion-matrix

# %% [markdown]
# ## <font color='Aquamarine'>Create labels</font>

# %%
#create labels
classes=[]
filename='C:/Users/darsh/Documents/My Files/Brain-Tumor-Classification-DataSet-master'
for sub_folder in os.listdir(os.path.join(filename,'Training')):
    classes.append(sub_folder)
print(classes)
# Out:
# ['glioma_tumor', 'meningioma_tumor', 'no_tumor', 'pituitary_tumor']

# %% [markdown]
# ## <font color='Aquamarine'>Resize images and put together Training and Testing folder</font>

# %%
#resize images and put together Training and Testing folder

X_train = []
y_train = []
image_size = 160
for i in classes:
    path_train = os.path.join(filename,'Training',i)
    for j in tqdm(os.listdir(path_train)): #Instantly make your loops show a smart progress meter 
        img = cv2.imread(os.path.join(path_train,j))
        img = cv2.resize(img,(image_size, image_size))
        X_train.append(img)
        y_train.append(i)
    path_test = os.path.join(filename,'Testing',i)
    for j in tqdm(os.listdir(path_test)):
        img = cv2.imread(os.path.join(path_test,j))
        img = cv2.resize(img,(image_size,image_size))
        X_train.append(img)
        y_train.append(i)
        
X_train = np.array(X_train)
y_train = np.array(y_train)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 826/826 [00:02<00:00, 308.07it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 363.40it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 822/822 [00:02<00:00, 333.76it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 115/115 [00:00<00:00, 426.64it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 395/395 [00:01<00:00, 360.45it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 105/105 [00:00<00:00, 587.10it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 827/827 [00:03<00:00, 249.00it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 74/74 [00:00<00:00, 90.23it/s]

# %% [markdown]
# ## <font color='Aquamarine'>Data augmentation and splitting</font>

# %%
#data augmentation
X_train, y_train = shuffle(X_train,y_train, random_state=42)
datagen = ImageDataGenerator(
    rotation_range=7, #rotate images
    width_shift_range=0.05,
    height_shift_range=0.05, #shift image in horizontal and vertical axis
    zoom_range=0.1, #zoom images
    horizontal_flip=True)

datagen.fit(X_train)
X_train.shape
lb = LabelEncoder()

#train and test splitting 
X_train,X_test,y_train,y_test = train_test_split(X_train,y_train, test_size=0.15,random_state=42,stratify=y_train)

labels_train=lb.fit(y_train)
y_train=lb.transform(y_train)
y_test=lb.transform(y_test)

# %% [markdown]
# ## <font color='Aquamarine'>Load EfficientNetB3</font>

# %%
print(y_train[:10])

#load EfficientNet
EfficientNet=EfficientNetB3(weights='imagenet', include_top=False,input_shape=(image_size,image_size,3))
# Out:
# [3 1 1 2 0 3 2 3 1 1]

# %% [markdown]
# ## <font color='Aquamarine'>Train the model</font>

# %%
#train the model
tf.random.set_seed(45)
model = EfficientNet.output
model = tf.keras.layers.GlobalAveragePooling2D()(model)
model = tf.keras.layers.Dropout(rate=0.55)(model)
model = tf.keras.layers.Dense(60,activation='elu',kernel_initializer='GlorotNormal')(model)
model = tf.keras.layers.Dropout(rate=0.3)(model)
model = tf.keras.layers.Dense(4,activation='softmax')(model)
model = tf.keras.models.Model(inputs=EfficientNet.input, outputs = model)
opt = Adam(
    learning_rate=0.000016, beta_1=0.91, beta_2=0.9994,
    epsilon=1e-08)

model.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
# summarize the model
print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 160, 160, 3  0           []
#                                 )]
#
#  rescaling (Rescaling)          (None, 160, 160, 3)  0           ['input_1[0][0]']
#
#  normalization (Normalization)  (None, 160, 160, 3)  7           ['rescaling[0][0]']
#
#  tf.math.truediv (TFOpLambda)   (None, 160, 160, 3)  0           ['normalization[0][0]']
#
#  stem_conv_pad (ZeroPadding2D)  (None, 161, 161, 3)  0           ['tf.math.truediv[0][0]']
#
#  stem_conv (Conv2D)             (None, 80, 80, 40)   1080        ['stem_conv_pad[0][0]']
#
#  stem_bn (BatchNormalization)   (None, 80, 80, 40)   160         ['stem_conv[0][0]']
#
#  stem_activation (Activation)   (None, 80, 80, 40)   0           ['stem_bn[0][0]']
#
#  block1a_dwconv (DepthwiseConv2  (None, 80, 80, 40)  360         ['stem_activation[0][0]']
#  D)
#
#  block1a_bn (BatchNormalization  (None, 80, 80, 40)  160         ['block1a_dwconv[0][0]']
#  )
#
#  block1a_activation (Activation  (None, 80, 80, 40)  0           ['block1a_bn[0][0]']
#  )
#
#  block1a_se_squeeze (GlobalAver  (None, 40)          0           ['block1a_activation[0][0]']
#  agePooling2D)
#
#  block1a_se_reshape (Reshape)   (None, 1, 1, 40)     0           ['block1a_se_squeeze[0][0]']
#
#  block1a_se_reduce (Conv2D)     (None, 1, 1, 10)     410         ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)     (None, 1, 1, 40)     440         ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multiply)   (None, 80, 80, 40)   0           ['block1a_activation[0][0]',
#                                                                   'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv2D)  (None, 80, 80, 24)   960         ['block1a_se_excite[0][0]']
#
#  block1a_project_bn (BatchNorma  (None, 80, 80, 24)  96          ['block1a_project_conv[0][0]']
#  lization)
#
#  block1b_dwconv (DepthwiseConv2  (None, 80, 80, 24)  216         ['block1a_project_bn[0][0]']
#  D)
#
#  block1b_bn (BatchNormalization  (None, 80, 80, 24)  96          ['block1b_dwconv[0][0]']
#  )
#
#  block1b_activation (Activation  (None, 80, 80, 24)  0           ['block1b_bn[0][0]']
#  )
#
#  block1b_se_squeeze (GlobalAver  (None, 24)          0           ['block1b_activation[0][0]']
#  agePooling2D)
#
#  block1b_se_reshape (Reshape)   (None, 1, 1, 24)     0           ['block1b_se_squeeze[0][0]']
#
#  block1b_se_reduce (Conv2D)     (None, 1, 1, 6)      150         ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)     (None, 1, 1, 24)     168         ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multiply)   (None, 80, 80, 24)   0           ['block1b_activation[0][0]',
#                                                                   'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv2D)  (None, 80, 80, 24)   576         ['block1b_se_excite[0][0]']
#
#  block1b_project_bn (BatchNorma  (None, 80, 80, 24)  96          ['block1b_project_conv[0][0]']
#  lization)
#
#  block1b_drop (Dropout)         (None, 80, 80, 24)   0           ['block1b_project_bn[0][0]']
#
#  block1b_add (Add)              (None, 80, 80, 24)   0           ['block1b_drop[0][0]',
#                                                                   'block1a_project_bn[0][0]']
#
#  block2a_expand_conv (Conv2D)   (None, 80, 80, 144)  3456        ['block1b_add[0][0]']
#
#  block2a_expand_bn (BatchNormal  (None, 80, 80, 144)  576        ['block2a_expand_conv[0][0]']
#  ization)
#
#  block2a_expand_activation (Act  (None, 80, 80, 144)  0          ['block2a_expand_bn[0][0]']
#  ivation)
#
#  block2a_dwconv_pad (ZeroPaddin  (None, 81, 81, 144)  0          ['block2a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block2a_dwconv (DepthwiseConv2  (None, 40, 40, 144)  1296       ['block2a_dwconv_pad[0][0]']
#  D)
#
#  block2a_bn (BatchNormalization  (None, 40, 40, 144)  576        ['block2a_dwconv[0][0]']
#  )
#
#  block2a_activation (Activation  (None, 40, 40, 144)  0          ['block2a_bn[0][0]']
#  )
#
#  block2a_se_squeeze (GlobalAver  (None, 144)         0           ['block2a_activation[0][0]']
#  agePooling2D)
#
#  block2a_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block2a_se_squeeze[0][0]']
#
#  block2a_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multiply)   (None, 40, 40, 144)  0           ['block2a_activation[0][0]',
#                                                                   'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv2D)  (None, 40, 40, 32)   4608        ['block2a_se_excite[0][0]']
#
#  block2a_project_bn (BatchNorma  (None, 40, 40, 32)  128         ['block2a_project_conv[0][0]']
#  lization)
#
#  block2b_expand_conv (Conv2D)   (None, 40, 40, 192)  6144        ['block2a_project_bn[0][0]']
#
#  block2b_expand_bn (BatchNormal  (None, 40, 40, 192)  768        ['block2b_expand_conv[0][0]']
#  ization)
#
#  block2b_expand_activation (Act  (None, 40, 40, 192)  0          ['block2b_expand_bn[0][0]']
#  ivation)
#
#  block2b_dwconv (DepthwiseConv2  (None, 40, 40, 192)  1728       ['block2b_expand_activation[0][0]
#  D)                                                              ']
#
#  block2b_bn (BatchNormalization  (None, 40, 40, 192)  768        ['block2b_dwconv[0][0]']
#  )
#
#  block2b_activation (Activation  (None, 40, 40, 192)  0          ['block2b_bn[0][0]']
#  )
#
#  block2b_se_squeeze (GlobalAver  (None, 192)         0           ['block2b_activation[0][0]']
#  agePooling2D)
#
#  block2b_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block2b_se_squeeze[0][0]']
#
#  block2b_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multiply)   (None, 40, 40, 192)  0           ['block2b_activation[0][0]',
#                                                                   'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv2D)  (None, 40, 40, 32)   6144        ['block2b_se_excite[0][0]']
#
#  block2b_project_bn (BatchNorma  (None, 40, 40, 32)  128         ['block2b_project_conv[0][0]']
#  lization)
#
#  block2b_drop (Dropout)         (None, 40, 40, 32)   0           ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)              (None, 40, 40, 32)   0           ['block2b_drop[0][0]',
#                                                                   'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2D)   (None, 40, 40, 192)  6144        ['block2b_add[0][0]']
#
#  block2c_expand_bn (BatchNormal  (None, 40, 40, 192)  768        ['block2c_expand_conv[0][0]']
#  ization)
#
#  block2c_expand_activation (Act  (None, 40, 40, 192)  0          ['block2c_expand_bn[0][0]']
#  ivation)
#
#  block2c_dwconv (DepthwiseConv2  (None, 40, 40, 192)  1728       ['block2c_expand_activation[0][0]
#  D)                                                              ']
#
#  block2c_bn (BatchNormalization  (None, 40, 40, 192)  768        ['block2c_dwconv[0][0]']
#  )
#
#  block2c_activation (Activation  (None, 40, 40, 192)  0          ['block2c_bn[0][0]']
#  )
#
#  block2c_se_squeeze (GlobalAver  (None, 192)         0           ['block2c_activation[0][0]']
#  agePooling2D)
#
#  block2c_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block2c_se_squeeze[0][0]']
#
#  block2c_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multiply)   (None, 40, 40, 192)  0           ['block2c_activation[0][0]',
#                                                                   'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv2D)  (None, 40, 40, 32)   6144        ['block2c_se_excite[0][0]']
#
#  block2c_project_bn (BatchNorma  (None, 40, 40, 32)  128         ['block2c_project_conv[0][0]']
#  lization)
#
#  block2c_drop (Dropout)         (None, 40, 40, 32)   0           ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)              (None, 40, 40, 32)   0           ['block2c_drop[0][0]',
#                                                                   'block2b_add[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 40, 40, 192)  6144        ['block2c_add[0][0]']
#
#  block3a_expand_bn (BatchNormal  (None, 40, 40, 192)  768        ['block3a_expand_conv[0][0]']
#  ization)
#
#  block3a_expand_activation (Act  (None, 40, 40, 192)  0          ['block3a_expand_bn[0][0]']
#  ivation)
#
#  block3a_dwconv_pad (ZeroPaddin  (None, 43, 43, 192)  0          ['block3a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block3a_dwconv (DepthwiseConv2  (None, 20, 20, 192)  4800       ['block3a_dwconv_pad[0][0]']
#  D)
#
#  block3a_bn (BatchNormalization  (None, 20, 20, 192)  768        ['block3a_dwconv[0][0]']
#  )
#
#  block3a_activation (Activation  (None, 20, 20, 192)  0          ['block3a_bn[0][0]']
#  )
#
#  block3a_se_squeeze (GlobalAver  (None, 192)         0           ['block3a_activation[0][0]']
#  agePooling2D)
#
#  block3a_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block3a_se_squeeze[0][0]']
#
#  block3a_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multiply)   (None, 20, 20, 192)  0           ['block3a_activation[0][0]',
#                                                                   'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv2D)  (None, 20, 20, 48)   9216        ['block3a_se_excite[0][0]']
#
#  block3a_project_bn (BatchNorma  (None, 20, 20, 48)  192         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 20, 20, 288)  13824       ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 20, 20, 288)  1152       ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 20, 20, 288)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_dwconv (DepthwiseConv2  (None, 20, 20, 288)  7200       ['block3b_expand_activation[0][0]
#  D)                                                              ']
#
#  block3b_bn (BatchNormalization  (None, 20, 20, 288)  1152       ['block3b_dwconv[0][0]']
#  )
#
#  block3b_activation (Activation  (None, 20, 20, 288)  0          ['block3b_bn[0][0]']
#  )
#
#  block3b_se_squeeze (GlobalAver  (None, 288)         0           ['block3b_activation[0][0]']
#  agePooling2D)
#  block3b_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block3b_se_squeeze[0][0]']
#
#  block3b_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multiply)   (None, 20, 20, 288)  0           ['block3b_activation[0][0]',
#                                                                   'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv2D)  (None, 20, 20, 48)   13824       ['block3b_se_excite[0][0]']
#
#  block3b_project_bn (BatchNorma  (None, 20, 20, 48)  192         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_drop (Dropout)         (None, 20, 20, 48)   0           ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)              (None, 20, 20, 48)   0           ['block3b_drop[0][0]',
#                                                                   'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2D)   (None, 20, 20, 288)  13824       ['block3b_add[0][0]']
#
#  block3c_expand_bn (BatchNormal  (None, 20, 20, 288)  1152       ['block3c_expand_conv[0][0]']
#  ization)
#
#  block3c_expand_activation (Act  (None, 20, 20, 288)  0          ['block3c_expand_bn[0][0]']
#  ivation)
#
#  block3c_dwconv (DepthwiseConv2  (None, 20, 20, 288)  7200       ['block3c_expand_activation[0][0]
#  D)                                                              ']
#
#  block3c_bn (BatchNormalization  (None, 20, 20, 288)  1152       ['block3c_dwconv[0][0]']
#  )
#
#  block3c_activation (Activation  (None, 20, 20, 288)  0          ['block3c_bn[0][0]']
#  )
#
#  block3c_se_squeeze (GlobalAver  (None, 288)         0           ['block3c_activation[0][0]']
#  agePooling2D)
#
#  block3c_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block3c_se_squeeze[0][0]']
#
#  block3c_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block3c_se_reshape[0][0]']
#
#  block3c_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block3c_se_reduce[0][0]']
#
#  block3c_se_excite (Multiply)   (None, 20, 20, 288)  0           ['block3c_activation[0][0]',
#                                                                   'block3c_se_expand[0][0]']
#
#  block3c_project_conv (Conv2D)  (None, 20, 20, 48)   13824       ['block3c_se_excite[0][0]']
#
#  block3c_project_bn (BatchNorma  (None, 20, 20, 48)  192         ['block3c_project_conv[0][0]']
#  lization)
#
#  block3c_drop (Dropout)         (None, 20, 20, 48)   0           ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)              (None, 20, 20, 48)   0           ['block3c_drop[0][0]',
#                                                                   'block3b_add[0][0]']
#
#  block4a_expand_conv (Conv2D)   (None, 20, 20, 288)  13824       ['block3c_add[0][0]']
#
#  block4a_expand_bn (BatchNormal  (None, 20, 20, 288)  1152       ['block4a_expand_conv[0][0]']
#  ization)
#
#  block4a_expand_activation (Act  (None, 20, 20, 288)  0          ['block4a_expand_bn[0][0]']
#  ivation)
#
#  block4a_dwconv_pad (ZeroPaddin  (None, 21, 21, 288)  0          ['block4a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block4a_dwconv (DepthwiseConv2  (None, 10, 10, 288)  2592       ['block4a_dwconv_pad[0][0]']
#  D)
#
#  block4a_bn (BatchNormalization  (None, 10, 10, 288)  1152       ['block4a_dwconv[0][0]']
#  )
#
#  block4a_activation (Activation  (None, 10, 10, 288)  0          ['block4a_bn[0][0]']
#  )
#
#  block4a_se_squeeze (GlobalAver  (None, 288)         0           ['block4a_activation[0][0]']
#  agePooling2D)
#
#  block4a_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block4a_se_squeeze[0][0]']
#  block4a_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multiply)   (None, 10, 10, 288)  0           ['block4a_activation[0][0]',
#                                                                   'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv2D)  (None, 10, 10, 96)   27648       ['block4a_se_excite[0][0]']
#
#  block4a_project_bn (BatchNorma  (None, 10, 10, 96)  384         ['block4a_project_conv[0][0]']
#  lization)
#
#  block4b_expand_conv (Conv2D)   (None, 10, 10, 576)  55296       ['block4a_project_bn[0][0]']
#
#  block4b_expand_bn (BatchNormal  (None, 10, 10, 576)  2304       ['block4b_expand_conv[0][0]']
#  ization)
#
#  block4b_expand_activation (Act  (None, 10, 10, 576)  0          ['block4b_expand_bn[0][0]']
#  ivation)
#
#  block4b_dwconv (DepthwiseConv2  (None, 10, 10, 576)  5184       ['block4b_expand_activation[0][0]
#  D)                                                              ']
#
#  block4b_bn (BatchNormalization  (None, 10, 10, 576)  2304       ['block4b_dwconv[0][0]']
#  )
#
#  block4b_activation (Activation  (None, 10, 10, 576)  0          ['block4b_bn[0][0]']
#  )
#
#  block4b_se_squeeze (GlobalAver  (None, 576)         0           ['block4b_activation[0][0]']
#  agePooling2D)
#
#  block4b_se_reshape (Reshape)   (None, 1, 1, 576)    0           ['block4b_se_squeeze[0][0]']
#
#  block4b_se_reduce (Conv2D)     (None, 1, 1, 24)     13848       ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)     (None, 1, 1, 576)    14400       ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multiply)   (None, 10, 10, 576)  0           ['block4b_activation[0][0]',
#                                                                   'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv2D)  (None, 10, 10, 96)   55296       ['block4b_se_excite[0][0]']
#
#  block4b_project_bn (BatchNorma  (None, 10, 10, 96)  384         ['block4b_project_conv[0][0]']
#  lization)
#
#  block4b_drop (Dropout)         (None, 10, 10, 96)   0           ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)              (None, 10, 10, 96)   0           ['block4b_drop[0][0]',
#                                                                   'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2D)   (None, 10, 10, 576)  55296       ['block4b_add[0][0]']
#
#  block4c_expand_bn (BatchNormal  (None, 10, 10, 576)  2304       ['block4c_expand_conv[0][0]']
#  ization)
#
#  block4c_expand_activation (Act  (None, 10, 10, 576)  0          ['block4c_expand_bn[0][0]']
#  ivation)
#
#  block4c_dwconv (DepthwiseConv2  (None, 10, 10, 576)  5184       ['block4c_expand_activation[0][0]
#  D)                                                              ']
#
#  block4c_bn (BatchNormalization  (None, 10, 10, 576)  2304       ['block4c_dwconv[0][0]']
#  )
#
#  block4c_activation (Activation  (None, 10, 10, 576)  0          ['block4c_bn[0][0]']
#  )
#
#  block4c_se_squeeze (GlobalAver  (None, 576)         0           ['block4c_activation[0][0]']
#  agePooling2D)
#
#  block4c_se_reshape (Reshape)   (None, 1, 1, 576)    0           ['block4c_se_squeeze[0][0]']
#
#  block4c_se_reduce (Conv2D)     (None, 1, 1, 24)     13848       ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)     (None, 1, 1, 576)    14400       ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multiply)   (None, 10, 10, 576)  0           ['block4c_activation[0][0]',
#                                                                   'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv2D)  (None, 10, 10, 96)   55296       ['block4c_se_excite[0][0]']
#
#  block4c_project_bn (BatchNorma  (None, 10, 10, 96)  384         ['block4c_project_conv[0][0]']
#  lization)
#
#  block4c_drop (Dropout)         (None, 10, 10, 96)   0           ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)              (None, 10, 10, 96)   0           ['block4c_drop[0][0]',
#                                                                   'block4b_add[0][0]']
#
#  block4d_expand_conv (Conv2D)   (None, 10, 10, 576)  55296       ['block4c_add[0][0]']
#
#  block4d_expand_bn (BatchNormal  (None, 10, 10, 576)  2304       ['block4d_expand_conv[0][0]']
#  ization)
#
#  block4d_expand_activation (Act  (None, 10, 10, 576)  0          ['block4d_expand_bn[0][0]']
#  ivation)
#
#  block4d_dwconv (DepthwiseConv2  (None, 10, 10, 576)  5184       ['block4d_expand_activation[0][0]
#  D)                                                              ']
#
#  block4d_bn (BatchNormalization  (None, 10, 10, 576)  2304       ['block4d_dwconv[0][0]']
#  )
#
#  block4d_activation (Activation  (None, 10, 10, 576)  0          ['block4d_bn[0][0]']
#  )
#
#  block4d_se_squeeze (GlobalAver  (None, 576)         0           ['block4d_activation[0][0]']
#  agePooling2D)
#
#  block4d_se_reshape (Reshape)   (None, 1, 1, 576)    0           ['block4d_se_squeeze[0][0]']
#
#  block4d_se_reduce (Conv2D)     (None, 1, 1, 24)     13848       ['block4d_se_reshape[0][0]']
#
#  block4d_se_expand (Conv2D)     (None, 1, 1, 576)    14400       ['block4d_se_reduce[0][0]']
#
#  block4d_se_excite (Multiply)   (None, 10, 10, 576)  0           ['block4d_activation[0][0]',
#                                                                   'block4d_se_expand[0][0]']
#
#  block4d_project_conv (Conv2D)  (None, 10, 10, 96)   55296       ['block4d_se_excite[0][0]']
#
#  block4d_project_bn (BatchNorma  (None, 10, 10, 96)  384         ['block4d_project_conv[0][0]']
#  lization)
#
#  block4d_drop (Dropout)         (None, 10, 10, 96)   0           ['block4d_project_bn[0][0]']
#
#  block4d_add (Add)              (None, 10, 10, 96)   0           ['block4d_drop[0][0]',
#                                                                   'block4c_add[0][0]']
#
#  block4e_expand_conv (Conv2D)   (None, 10, 10, 576)  55296       ['block4d_add[0][0]']
#
#  block4e_expand_bn (BatchNormal  (None, 10, 10, 576)  2304       ['block4e_expand_conv[0][0]']
#  ization)
#
#  block4e_expand_activation (Act  (None, 10, 10, 576)  0          ['block4e_expand_bn[0][0]']
#  ivation)
#
#  block4e_dwconv (DepthwiseConv2  (None, 10, 10, 576)  5184       ['block4e_expand_activation[0][0]
#  D)                                                              ']
#
#  block4e_bn (BatchNormalization  (None, 10, 10, 576)  2304       ['block4e_dwconv[0][0]']
#  )
#
#  block4e_activation (Activation  (None, 10, 10, 576)  0          ['block4e_bn[0][0]']
#  )
#
#  block4e_se_squeeze (GlobalAver  (None, 576)         0           ['block4e_activation[0][0]']
#  agePooling2D)
#
#  block4e_se_reshape (Reshape)   (None, 1, 1, 576)    0           ['block4e_se_squeeze[0][0]']
#
#  block4e_se_reduce (Conv2D)     (None, 1, 1, 24)     13848       ['block4e_se_reshape[0][0]']
#
#  block4e_se_expand (Conv2D)     (None, 1, 1, 576)    14400       ['block4e_se_reduce[0][0]']
#
#  block4e_se_excite (Multiply)   (None, 10, 10, 576)  0           ['block4e_activation[0][0]',
# ...
#  block6e_bn (BatchNormalization  (None, 5, 5, 1392)  5568        ['block6e_dwconv[0][0]']
#  )
#
#  block6e_activation (Activation  (None, 5, 5, 1392)  0           ['block6e_bn[0][0]']
#  )
#
#  block6e_se_squeeze (GlobalAver  (None, 1392)        0           ['block6e_activation[0][0]']
#  agePooling2D)
#
#  block6e_se_reshape (Reshape)   (None, 1, 1, 1392)   0           ['block6e_se_squeeze[0][0]']
#
#  block6e_se_reduce (Conv2D)     (None, 1, 1, 58)     80794       ['block6e_se_reshape[0][0]']
#
#  block6e_se_expand (Conv2D)     (None, 1, 1, 1392)   82128       ['block6e_se_reduce[0][0]']
#
#  block6e_se_excite (Multiply)   (None, 5, 5, 1392)   0           ['block6e_activation[0][0]',
#                                                                   'block6e_se_expand[0][0]']
#
#  block6e_project_conv (Conv2D)  (None, 5, 5, 232)    322944      ['block6e_se_excite[0][0]']
#
#  block6e_project_bn (BatchNorma  (None, 5, 5, 232)   928         ['block6e_project_conv[0][0]']
#  lization)
#
#  block6e_drop (Dropout)         (None, 5, 5, 232)    0           ['block6e_project_bn[0][0]']
#
#  block6e_add (Add)              (None, 5, 5, 232)    0           ['block6e_drop[0][0]',
#                                                                   'block6d_add[0][0]']
#
#  block6f_expand_conv (Conv2D)   (None, 5, 5, 1392)   322944      ['block6e_add[0][0]']
#
#  block6f_expand_bn (BatchNormal  (None, 5, 5, 1392)  5568        ['block6f_expand_conv[0][0]']
#  ization)
#
#  block6f_expand_activation (Act  (None, 5, 5, 1392)  0           ['block6f_expand_bn[0][0]']
#  ivation)
#
#  block6f_dwconv (DepthwiseConv2  (None, 5, 5, 1392)  34800       ['block6f_expand_activation[0][0]
#  D)                                                              ']
#
#  block6f_bn (BatchNormalization  (None, 5, 5, 1392)  5568        ['block6f_dwconv[0][0]']
#  )
#
#  block6f_activation (Activation  (None, 5, 5, 1392)  0           ['block6f_bn[0][0]']
#  )
#
#  block6f_se_squeeze (GlobalAver  (None, 1392)        0           ['block6f_activation[0][0]']
#  agePooling2D)
#
#  block6f_se_reshape (Reshape)   (None, 1, 1, 1392)   0           ['block6f_se_squeeze[0][0]']
#
#  block6f_se_reduce (Conv2D)     (None, 1, 1, 58)     80794       ['block6f_se_reshape[0][0]']
#
#  block6f_se_expand (Conv2D)     (None, 1, 1, 1392)   82128       ['block6f_se_reduce[0][0]']
#
#  block6f_se_excite (Multiply)   (None, 5, 5, 1392)   0           ['block6f_activation[0][0]',
#                                                                   'block6f_se_expand[0][0]']
#
#  block6f_project_conv (Conv2D)  (None, 5, 5, 232)    322944      ['block6f_se_excite[0][0]']
#
#  block6f_project_bn (BatchNorma  (None, 5, 5, 232)   928         ['block6f_project_conv[0][0]']
#  lization)
#
#  block6f_drop (Dropout)         (None, 5, 5, 232)    0           ['block6f_project_bn[0][0]']
#
#  block6f_add (Add)              (None, 5, 5, 232)    0           ['block6f_drop[0][0]',
#                                                                   'block6e_add[0][0]']
#
#  block7a_expand_conv (Conv2D)   (None, 5, 5, 1392)   322944      ['block6f_add[0][0]']
#
#  block7a_expand_bn (BatchNormal  (None, 5, 5, 1392)  5568        ['block7a_expand_conv[0][0]']
#  ization)
#
#  block7a_expand_activation (Act  (None, 5, 5, 1392)  0           ['block7a_expand_bn[0][0]']
#  ivation)
#
#  block7a_dwconv (DepthwiseConv2  (None, 5, 5, 1392)  12528       ['block7a_expand_activation[0][0]
#  D)                                                              ']
#
#  block7a_bn (BatchNormalization  (None, 5, 5, 1392)  5568        ['block7a_dwconv[0][0]']
#  )
#
#  block7a_activation (Activation  (None, 5, 5, 1392)  0           ['block7a_bn[0][0]']
#  )
#
#  block7a_se_squeeze (GlobalAver  (None, 1392)        0           ['block7a_activation[0][0]']
#  agePooling2D)
#
#  block7a_se_reshape (Reshape)   (None, 1, 1, 1392)   0           ['block7a_se_squeeze[0][0]']
#
#  block7a_se_reduce (Conv2D)     (None, 1, 1, 58)     80794       ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)     (None, 1, 1, 1392)   82128       ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multiply)   (None, 5, 5, 1392)   0           ['block7a_activation[0][0]',
#                                                                   'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv2D)  (None, 5, 5, 384)    534528      ['block7a_se_excite[0][0]']
#
#  block7a_project_bn (BatchNorma  (None, 5, 5, 384)   1536        ['block7a_project_conv[0][0]']
#  lization)
#
#  block7b_expand_conv (Conv2D)   (None, 5, 5, 2304)   884736      ['block7a_project_bn[0][0]']
#
#  block7b_expand_bn (BatchNormal  (None, 5, 5, 2304)  9216        ['block7b_expand_conv[0][0]']
#  ization)
#
#  block7b_expand_activation (Act  (None, 5, 5, 2304)  0           ['block7b_expand_bn[0][0]']
#  ivation)
#
#  block7b_dwconv (DepthwiseConv2  (None, 5, 5, 2304)  20736       ['block7b_expand_activation[0][0]
#  D)                                                              ']
#
#  block7b_bn (BatchNormalization  (None, 5, 5, 2304)  9216        ['block7b_dwconv[0][0]']
#  )
#
#  block7b_activation (Activation  (None, 5, 5, 2304)  0           ['block7b_bn[0][0]']
#  )
#
#  block7b_se_squeeze (GlobalAver  (None, 2304)        0           ['block7b_activation[0][0]']
#  agePooling2D)
#
#  block7b_se_reshape (Reshape)   (None, 1, 1, 2304)   0           ['block7b_se_squeeze[0][0]']
#
#  block7b_se_reduce (Conv2D)     (None, 1, 1, 96)     221280      ['block7b_se_reshape[0][0]']
#
#  block7b_se_expand (Conv2D)     (None, 1, 1, 2304)   223488      ['block7b_se_reduce[0][0]']
#
#  block7b_se_excite (Multiply)   (None, 5, 5, 2304)   0           ['block7b_activation[0][0]',
#                                                                   'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv2D)  (None, 5, 5, 384)    884736      ['block7b_se_excite[0][0]']
#
#  block7b_project_bn (BatchNorma  (None, 5, 5, 384)   1536        ['block7b_project_conv[0][0]']
#  lization)
#
#  block7b_drop (Dropout)         (None, 5, 5, 384)    0           ['block7b_project_bn[0][0]']
#
#  block7b_add (Add)              (None, 5, 5, 384)    0           ['block7b_drop[0][0]',
#                                                                   'block7a_project_bn[0][0]']
#
#  top_conv (Conv2D)              (None, 5, 5, 1536)   589824      ['block7b_add[0][0]']
#
#  top_bn (BatchNormalization)    (None, 5, 5, 1536)   6144        ['top_conv[0][0]']
#
#  top_activation (Activation)    (None, 5, 5, 1536)   0           ['top_bn[0][0]']
#
#  global_average_pooling2d (Glob  (None, 1536)        0           ['top_activation[0][0]']
#  alAveragePooling2D)
#
#  dropout (Dropout)              (None, 1536)         0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense (Dense)                  (None, 60)           92220       ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 60)           0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 4)            244         ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 10,875,999
# Trainable params: 10,788,696
# Non-trainable params: 87,303
# __________________________________________________________________________________________________
# None

# %%
print("Layers in the model: ", len(model.layers))
# Out:
# Layers in the model:  390

# %%
# fit the model
savePath = 'C:/Users/darsh/Documents/My Files/Brain-Tumor-Classification-DataSet-master/Model Checkpoints/Model-{epoch:02d}-{val_loss:.2f}.hdf5'
checkpoint = keras.callbacks.ModelCheckpoint(savePath, moniter = 'val_loss', verbose = 1, save_best_only = True, mode = 'min')

early_stopping_cb=keras.callbacks.EarlyStopping(patience=9,restore_best_weights=True)

callbacks_list = [checkpoint, early_stopping_cb ]

history=model.fit(X_train ,y_train,validation_data = (X_test,y_test),epochs=90,
    batch_size=13,callbacks=callbacks_list)
# Out:
# Epoch 1/90
# 214/214 [==============================] - 67s 226ms/step - loss: 1.3196 - accuracy: 0.4117 - val_loss: 1.2023 - val_accuracy: 0.4857
#
# Epoch 00001: val_loss improved from inf to 1.20233, saving model to C:/Users/darsh/Documents/My Files/Brain-Tumor-Classification-DataSet-master/Model Checkpoints\Model-01-1.20.hdf5
# C:\Users\darsh\anaconda3\envs\Trial\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 2/90
# 214/214 [==============================] - 42s 198ms/step - loss: 0.9008 - accuracy: 0.6391 - val_loss: 1.0067 - val_accuracy: 0.5980
#
# Epoch 00002: val_loss improved from 1.20233 to 1.00670, saving model to C:/Users/darsh/Documents/My Files/Brain-Tumor-Classification-DataSet-master/Model Checkpoints\Model-02-1.01.hdf5
# Epoch 3/90
# 214/214 [==============================] - 42s 196ms/step - loss: 0.7154 - accuracy: 0.7246 - val_loss: 0.7646 - val_accuracy: 0.7429
#
# Epoch 00003: val_loss improved from 1.00670 to 0.76462, saving model to C:/Users/darsh/Documents/My Files/Brain-Tumor-Classification-DataSet-master/Model Checkpoints\Model-03-0.76.hdf5
# Epoch 4/90
# 214/214 [==============================] - 42s 196ms/step - loss: 0.5989 - accuracy: 0.7718 - val_loss: 0.4590 - val_accuracy: 0.8469
#
# Epoch 00004: val_loss improved from 0.76462 to 0.45900, saving model to C:/Users/darsh/Documents/My Files/Brain-Tumor-Classification-DataSet-master/Model Checkpoints\Model-04-0.46.hdf5
# Epoch 5/90
# 214/214 [==============================] - 42s 196ms/step - loss: 0.5111 - accuracy: 0.8075 - val_loss: 0.3517 - val_accuracy: 0.8857
#
# Epoch 00005: val_loss improved from 0.45900 to 0.35172, saving model to C:/Users/darsh/Documents/My Files/Brain-Tumor-Classification-DataSet-master/Model Checkpoints\Model-05-0.35.hdf5
# Epoch 6/90
# 214/214 [==============================] - 42s 196ms/step - loss: 0.4293 - accuracy: 0.8468 - val_loss: 0.3039 - val_accuracy: 0.8959
#
# Epoch 00006: val_loss improved from 0.35172 to 0.30385, saving model to C:/Users/darsh/Documents/My Files/Brain-Tumor-Classification-DataSet-master/Model Checkpoints\Model-06-0.30.hdf5
# Epoch 7/90
# 214/214 [==============================] - 42s 197ms/step - loss: 0.3857 - accuracy: 0.8594 - val_loss: 0.2630 - val_accuracy: 0.9102
#
# Epoch 00007: val_loss improved from 0.30385 to 0.26299, saving model to C:/Users/darsh/Documents/My Files/Brain-Tumor-Classification-DataSet-master/Model Checkpoints\Model-07-0.26.hdf5
# Epoch 8/90
# 214/214 [==============================] - 42s 196ms/step - loss: 0.3549 - accuracy: 0.8731 - val_loss: 0.2524 - val_accuracy: 0.9061
#
# Epoch 00008: val_loss improved from 0.26299 to 0.25244, saving model to C:/Users/darsh/Documents/My Files/Brain-Tumor-Classification-DataSet-master/Model Checkpoints\Model-08-0.25.hdf5
# Epoch 9/90
# 214/214 [==============================] - 42s 196ms/step - loss: 0.2942 - accuracy: 0.9059 - val_loss: 0.2220 - val_accuracy: 0.9163
#
# Epoch 00009: val_loss improved from 0.25244 to 0.22197, saving model to C:/Users/darsh/Documents/My Files/Brain-Tumor-Classification-DataSet-master/Model Checkpoints\Model-09-0.22.hdf5
# Epoch 10/90
# 214/214 [==============================] - 42s 196ms/step - loss: 0.2821 - accuracy: 0.9045 - val_loss: 0.1949 - val_accuracy: 0.9327
#
# Epoch 00010: val_loss improved from 0.22197 to 0.19495, saving model to C:/Users/darsh/Documents/My Files/Brain-Tumor-Classification-DataSet-master/Model Checkpoints\Model-10-0.19.hdf5
# Epoch 11/90
# 214/214 [==============================] - 44s 204ms/step - loss: 0.2395 - accuracy: 0.9193 - val_loss: 0.1946 - val_accuracy: 0.9245
#
# Epoch 00011: val_loss improved from 0.19495 to 0.19456, saving model to C:/Users/darsh/Documents/My Files/Brain-Tumor-Classification-DataSet-master/Model Checkpoints\Model-11-0.19.hdf5
# Epoch 12/90
# 214/214 [==============================] - 43s 200ms/step - loss: 0.1894 - accuracy: 0.9366 - val_loss: 0.1744 - val_accuracy: 0.9367
#
# Epoch 00012: val_loss improved from 0.19456 to 0.17438, saving model to C:/Users/darsh/Documents/My Files/Brain-Tumor-Classification-DataSet-master/Model Checkpoints\Model-12-0.17.hdf5
# Epoch 13/90
# 214/214 [==============================] - 42s 195ms/step - loss: 0.1809 - accuracy: 0.9369 - val_loss: 0.1653 - val_accuracy: 0.9408
#
# Epoch 00013: val_loss improved from 0.17438 to 0.16534, saving model to C:/Users/darsh/Documents/My Files/Brain-Tumor-Classification-DataSet-master/Model Checkpoints\Model-13-0.17.hdf5
# Epoch 14/90
# 214/214 [==============================] - 42s 195ms/step - loss: 0.1568 - accuracy: 0.9474 - val_loss: 0.1580 - val_accuracy: 0.9429
#
# Epoch 00014: val_loss improved from 0.16534 to 0.15801, saving model to C:/Users/darsh/Documents/My Files/Brain-Tumor-Classification-DataSet-master/Model Checkpoints\Model-14-0.16.hdf5
# Epoch 15/90
# 214/214 [==============================] - 43s 200ms/step - loss: 0.1516 - accuracy: 0.9477 - val_loss: 0.1548 - val_accuracy: 0.9510
#
# Epoch 00015: val_loss improved from 0.15801 to 0.15475, saving model to C:/Users/darsh/Documents/My Files/Brain-Tumor-Classification-DataSet-master/Model Checkpoints\Model-15-0.15.hdf5
# Epoch 16/90
# 214/214 [==============================] - 42s 197ms/step - loss: 0.1375 - accuracy: 0.9531 - val_loss: 0.1397 - val_accuracy: 0.9531
#
# Epoch 00016: val_loss improved from 0.15475 to 0.13970, saving model to C:/Users/darsh/Documents/My Files/Brain-Tumor-Classification-DataSet-master/Model Checkpoints\Model-16-0.14.hdf5
# Epoch 17/90
# 214/214 [==============================] - 42s 195ms/step - loss: 0.1058 - accuracy: 0.9668 - val_loss: 0.1317 - val_accuracy: 0.9571
#
# Epoch 00017: val_loss improved from 0.13970 to 0.13166, saving model to C:/Users/darsh/Documents/My Files/Brain-Tumor-Classification-DataSet-master/Model Checkpoints\Model-17-0.13.hdf5
# Epoch 18/90
# 214/214 [==============================] - 42s 196ms/step - loss: 0.1041 - accuracy: 0.9640 - val_loss: 0.1324 - val_accuracy: 0.9571
#
# Epoch 00018: val_loss did not improve from 0.13166
# Epoch 19/90
# 214/214 [==============================] - 44s 204ms/step - loss: 0.1003 - accuracy: 0.9686 - val_loss: 0.1339 - val_accuracy: 0.9531
#
# Epoch 00019: val_loss did not improve from 0.13166
# Epoch 20/90
# 214/214 [==============================] - 44s 204ms/step - loss: 0.0872 - accuracy: 0.9733 - val_loss: 0.1237 - val_accuracy: 0.9571
#
# Epoch 00020: val_loss improved from 0.13166 to 0.12370, saving model to C:/Users/darsh/Documents/My Files/Brain-Tumor-Classification-DataSet-master/Model Checkpoints\Model-20-0.12.hdf5
# Epoch 21/90
# 214/214 [==============================] - 42s 197ms/step - loss: 0.0956 - accuracy: 0.9708 - val_loss: 0.1234 - val_accuracy: 0.9551
#
# Epoch 00021: val_loss improved from 0.12370 to 0.12338, saving model to C:/Users/darsh/Documents/My Files/Brain-Tumor-Classification-DataSet-master/Model Checkpoints\Model-21-0.12.hdf5
# Epoch 22/90
# 214/214 [==============================] - 42s 195ms/step - loss: 0.0813 - accuracy: 0.9740 - val_loss: 0.1210 - val_accuracy: 0.9612
#
# Epoch 00022: val_loss improved from 0.12338 to 0.12097, saving model to C:/Users/darsh/Documents/My Files/Brain-Tumor-Classification-DataSet-master/Model Checkpoints\Model-22-0.12.hdf5
# Epoch 23/90
# 214/214 [==============================] - 42s 196ms/step - loss: 0.0653 - accuracy: 0.9816 - val_loss: 0.1197 - val_accuracy: 0.9592
#
# Epoch 00023: val_loss improved from 0.12097 to 0.11967, saving model to C:/Users/darsh/Documents/My Files/Brain-Tumor-Classification-DataSet-master/Model Checkpoints\Model-23-0.12.hdf5
# Epoch 24/90
# 214/214 [==============================] - 43s 199ms/step - loss: 0.0590 - accuracy: 0.9813 - val_loss: 0.1196 - val_accuracy: 0.9592
#
# Epoch 00024: val_loss improved from 0.11967 to 0.11959, saving model to C:/Users/darsh/Documents/My Files/Brain-Tumor-Classification-DataSet-master/Model Checkpoints\Model-24-0.12.hdf5
# Epoch 25/90
# 214/214 [==============================] - 42s 196ms/step - loss: 0.0475 - accuracy: 0.9859 - val_loss: 0.1099 - val_accuracy: 0.9633
#
# Epoch 00025: val_loss improved from 0.11959 to 0.10987, saving model to C:/Users/darsh/Documents/My Files/Brain-Tumor-Classification-DataSet-master/Model Checkpoints\Model-25-0.11.hdf5
# Epoch 26/90
# 214/214 [==============================] - 42s 196ms/step - loss: 0.0488 - accuracy: 0.9859 - val_loss: 0.1129 - val_accuracy: 0.9633A: 2s - los
#
# Epoch 00026: val_loss did not improve from 0.10987
# Epoch 27/90
# 214/214 [==============================] - 42s 195ms/step - loss: 0.0527 - accuracy: 0.9841 - val_loss: 0.1120 - val_accuracy: 0.9673
#
# Epoch 00027: val_loss did not improve from 0.10987
# Epoch 28/90
# 214/214 [==============================] - 44s 203ms/step - loss: 0.0446 - accuracy: 0.9874 - val_loss: 0.1367 - val_accuracy: 0.9592
#
# Epoch 00028: val_loss did not improve from 0.10987
# Epoch 29/90
# 214/214 [==============================] - 44s 206ms/step - loss: 0.0412 - accuracy: 0.9863 - val_loss: 0.0941 - val_accuracy: 0.9673
#
# Epoch 00029: val_loss improved from 0.10987 to 0.09414, saving model to C:/Users/darsh/Documents/My Files/Brain-Tumor-Classification-DataSet-master/Model Checkpoints\Model-29-0.09.hdf5
# Epoch 30/90
# 214/214 [==============================] - 42s 195ms/step - loss: 0.0401 - accuracy: 0.9899 - val_loss: 0.0987 - val_accuracy: 0.9673
#
# Epoch 00030: val_loss did not improve from 0.09414
# Epoch 31/90
# 214/214 [==============================] - 43s 201ms/step - loss: 0.0337 - accuracy: 0.9899 - val_loss: 0.0950 - val_accuracy: 0.9714
#
# Epoch 00031: val_loss did not improve from 0.09414
# Epoch 32/90
# 214/214 [==============================] - 42s 195ms/step - loss: 0.0315 - accuracy: 0.9921 - val_loss: 0.0989 - val_accuracy: 0.9673
#
# Epoch 00032: val_loss did not improve from 0.09414
# Epoch 33/90
# 214/214 [==============================] - 42s 195ms/step - loss: 0.0433 - accuracy: 0.9852 - val_loss: 0.1071 - val_accuracy: 0.9714
#
# Epoch 00033: val_loss did not improve from 0.09414
# Epoch 34/90
# 214/214 [==============================] - 42s 196ms/step - loss: 0.0416 - accuracy: 0.9885 - val_loss: 0.1076 - val_accuracy: 0.9653
#
# Epoch 00034: val_loss did not improve from 0.09414
# Epoch 35/90
# 214/214 [==============================] - 42s 198ms/step - loss: 0.0358 - accuracy: 0.9892 - val_loss: 0.0898 - val_accuracy: 0.9714
#
# Epoch 00035: val_loss improved from 0.09414 to 0.08977, saving model to C:/Users/darsh/Documents/My Files/Brain-Tumor-Classification-DataSet-master/Model Checkpoints\Model-35-0.09.hdf5
# Epoch 36/90
# 214/214 [==============================] - 42s 196ms/step - loss: 0.0305 - accuracy: 0.9899 - val_loss: 0.0979 - val_accuracy: 0.9714
#
# Epoch 00036: val_loss did not improve from 0.08977
# Epoch 37/90
# 214/214 [==============================] - 49s 229ms/step - loss: 0.0312 - accuracy: 0.9899 - val_loss: 0.0807 - val_accuracy: 0.9694
#
# Epoch 00037: val_loss improved from 0.08977 to 0.08074, saving model to C:/Users/darsh/Documents/My Files/Brain-Tumor-Classification-DataSet-master/Model Checkpoints\Model-37-0.08.hdf5
# Epoch 38/90
# 214/214 [==============================] - 67s 314ms/step - loss: 0.0362 - accuracy: 0.9899 - val_loss: 0.0808 - val_accuracy: 0.9673
#
# Epoch 00038: val_loss did not improve from 0.08074
# Epoch 39/90
# 214/214 [==============================] - 67s 314ms/step - loss: 0.0326 - accuracy: 0.9885 - val_loss: 0.0901 - val_accuracy: 0.9653
#
# Epoch 00039: val_loss did not improve from 0.08074
# Epoch 40/90
# 214/214 [==============================] - 67s 313ms/step - loss: 0.0247 - accuracy: 0.9924 - val_loss: 0.0825 - val_accuracy: 0.9673
#
# Epoch 00040: val_loss did not improve from 0.08074
# Epoch 41/90
# 214/214 [==============================] - 59s 273ms/step - loss: 0.0338 - accuracy: 0.9906 - val_loss: 0.1037 - val_accuracy: 0.9633
#
# Epoch 00041: val_loss did not improve from 0.08074
# Epoch 42/90
# 214/214 [==============================] - 42s 195ms/step - loss: 0.0231 - accuracy: 0.9924 - val_loss: 0.0977 - val_accuracy: 0.9694
#
# Epoch 00042: val_loss did not improve from 0.08074
# Epoch 43/90
# 214/214 [==============================] - 43s 199ms/step - loss: 0.0228 - accuracy: 0.9932 - val_loss: 0.0943 - val_accuracy: 0.9714
#
# Epoch 00043: val_loss did not improve from 0.08074
# Epoch 44/90
# 214/214 [==============================] - 42s 196ms/step - loss: 0.0242 - accuracy: 0.9953 - val_loss: 0.1007 - val_accuracy: 0.9653
#
# Epoch 00044: val_loss did not improve from 0.08074
# Epoch 45/90
# 214/214 [==============================] - 42s 198ms/step - loss: 0.0250 - accuracy: 0.9924 - val_loss: 0.1143 - val_accuracy: 0.9653
#
# Epoch 00045: val_loss did not improve from 0.08074
# Epoch 46/90
# 214/214 [==============================] - 43s 200ms/step - loss: 0.0181 - accuracy: 0.9953 - val_loss: 0.1000 - val_accuracy: 0.9694
#
# Epoch 00046: val_loss did not improve from 0.08074

# %%
y_train.shape,y_test.shape
# Out:
# ((2774,), (490,))

# %% [markdown]
# ## <font color='Aquamarine'>Save the model</font>

# %%
# change directory
#os.chdir(r'../input/brain-tumor-classification-mri')
print(os.getcwd())

#save the model
model.save('C:/Users/darsh/Documents/My Files/Brain-Tumor-Classification-DataSet-master/Saved Model/EfficientNetB3.h5')
model.save_weights('C:/Users/darsh/Documents/My Files/Brain-Tumor-Classification-DataSet-master/Saved Model/EfficientNetB3_weights.h5')

#plot loss and accuracy
pd.DataFrame(history.history).plot(figsize=(8, 5))
#plt.grid(True)

#plt.gca().set_xlim(0,33)
plt.gca().set_ylim(0,1)
#plt.savefig('C:/Users/mahad/OneDrive/Desktop/brain/EfficientNetB3.png')
# Out:
# C:\Users\darsh\Downloads
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16520/3932061925.py in <module>
#       4
#       5 #save the model
# ----> 6 model.save('C:/Users/darsh/Documents/My Files/Brain-Tumor-Classification-DataSet-master/Saved Model/EfficientNetB3.h5')
#       7 model.save_weights('C:/Users/darsh/Documents/My Files/Brain-Tumor-Classification-DataSet-master/Saved Model/EfficientNetB3_weights.h5')
#       8
#
# NameError: name 'model' is not defined

# %%
loss, accuracy = model.evaluate(X_test,y_test)
#print accuracy    
print('Accuracy: %f' % (accuracy*100))
# Out:
# 16/16 [==============================] - 6s 232ms/step - loss: 0.0807 - accuracy: 0.9694
# Accuracy: 96.938777

# %%
newModel = keras.models.load_model('C:/Users/darsh/Documents/My Files/Brain-Tumor-Classification-DataSet-master/Saved Model/EfficientNetB3.h5')
newModel.load_weights('C:/Users/darsh/Documents/My Files/Brain-Tumor-Classification-DataSet-master/Saved Model/EfficientNetB3_weights.h5')

# %%
newloss, newaccuracy = newModel.evaluate(X_test,y_test)
#print accuracy    
print('Accuracy: %f' % (newaccuracy*100))
# Out:
# 16/16 [==============================] - 17s 924ms/step - loss: 0.0807 - accuracy: 0.9694
# Accuracy: 96.938777

# %%
#  More details about the model
'''
for i, layer in enumerate (model.layers):
    print (i, layer)
    try:
        print ("    ",layer.activation)
    except AttributeError:
        print('   no activation attribute')
#specific info about each layer
for i in range(len(model.layers)):
    print(f'{i}   {model.layers[i]}: \n{model.layers[i].get_config()} \n')
'''

#info about optimizers
model.optimizer.get_config()

# %% [markdown]
# ## <font color='Aquamarine'>Accuracy and Loss</font>

# %%
print(f'accuracy : {round(accuracy*100,3)} \n loss : {round(loss,3)}')
# Out:
# accuracy : 96.939
#  loss : 0.081

# %%
y_test_labels=lb.inverse_transform(y_test)

#predicted values
pred=np.argmax(model.predict(X_test),axis=1)
pred_labels=lb.inverse_transform(pred) #predicted labels

# %%
y_test_labels=lb.inverse_transform(y_test)

#predicted values
pred=np.argmax(newModel.predict(X_test),axis=1)
pred_labels=lb.inverse_transform(pred) #predicted labels
# Out:
# 16/16 [==============================] - 20s 1s/step

# %%
pd.Series(pred_labels).value_counts()
# Out:
# meningioma_tumor    141
# pituitary_tumor     138
# glioma_tumor        136
# no_tumor             75
# dtype: int64

# %% [markdown]
# ## <font color='Aquamarine'>Confusion Matrix</font>

# %%
cm = confusion_matrix(y_test,pred)
fig,ax= plt.subplots(figsize=(10.2,8.1))
a=sns.color_palette("winter_r")  #_r inverts the palette
sns.heatmap(cm, annot=True,fmt='g',linewidths=1,linecolor='white',robust=True,annot_kws={"size":18},cmap=a)
 #annot_kws: settings about annotations
ax.xaxis.set_ticklabels(classes); ax.yaxis.set_ticklabels(classes);
plt.yticks(va="center")
plt.title('Confusion Matrix',fontsize=18,pad=18)
plt.xlabel('Actual class',labelpad=22,fontsize=14)
plt.ylabel('Predicted class',labelpad=22,fontsize=14)
#plt.savefig(os.path.join('plots/','EfficientNetB3_confusion_matrix.png'), dpi=300)
# Out:
# Text(70.8, 0.5, 'Predicted class')

# %% [markdown]
# ## <font color='Aquamarine'>Model performance scores</font>

# %%
print(classification_report(y_test,pred,target_names=classes))
# Out:
#                   precision    recall  f1-score   support
#
#     glioma_tumor       0.97      0.95      0.96       139
# meningioma_tumor       0.96      0.96      0.96       141
#         no_tumor       0.99      0.99      0.99        75
#  pituitary_tumor       0.97      0.99      0.98       135
#
#         accuracy                           0.97       490
#        macro avg       0.97      0.97      0.97       490
#     weighted avg       0.97      0.97      0.97       490

# %%
import matplotlib.image as mpimg
#os.chdir('C:/Users/mahad/OneDrive/Desktop/brain')
TEST_DIR='C:/Users/darsh/Documents/My Files/Brain-Tumor-Classification-DataSet-master/Testing'
#fetch images from the original validation dataset and resize them in order to plot the images.
images=[] 
n_classes=4
z_max=20
for i,filenames in enumerate(os.listdir(TEST_DIR)): 
    dir_fold=os.path.join(TEST_DIR, filenames)
    print(dir_fold)
    class_images=[]
    z=0
    for filename in os.listdir(dir_fold):
        if z < z_max:
            img_path = os.path.join(dir_fold, filename)
            img = cv2.imread(img_path)
            img = cv2.resize(img,(image_size,image_size))
            class_images.append(img)
            z+=1
        else:
            break
    images.append(class_images)
images=images[:20]
# Out:
# C:/Users/darsh/Documents/My Files/Brain-Tumor-Classification-DataSet-master/Testing\glioma_tumor
# C:/Users/darsh/Documents/My Files/Brain-Tumor-Classification-DataSet-master/Testing\meningioma_tumor
# C:/Users/darsh/Documents/My Files/Brain-Tumor-Classification-DataSet-master/Testing\no_tumor
# C:/Users/darsh/Documents/My Files/Brain-Tumor-Classification-DataSet-master/Testing\pituitary_tumor

# %%
#here I plotted the images based on columns and z_max (defined by the user, 
#but it should be a multiple of the no of columns)
columns = 10
fig,axes=plt.subplots(int(len(images)*len(images[0])/columns),columns,figsize=(40,20))
fig.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.4)
for i,ind in enumerate(images):
    #print(images_class)
    fig.suptitle('Plot of some MRI images in the dataset',fontsize=47)
    for j, image in enumerate(ind):
        #print(j,image)
        axes[int((i)*(len(ind)/columns)+(int(j/columns))),j % columns].imshow(image)
        axes[int((i)*(len(ind)/columns)+(int(j/columns))),j % columns].set_title(f'{classes[i]}',pad=10)
#image_plotting(X_test[:1])
#plt.savefig(os.path.join('plots/','Some_MRI_images_in_the_dataset_white.png'), dpi=300,facecolor='w')

# %%
X_test_images=dict(zip(classes,[[],[],[],[]]))
for y,ele in enumerate(pred):
    for i,x in enumerate(X_test_images):
        #num=pred[ind]
        if ele==i:
            if len(X_test_images[classes[i]])<z_max:
                X_test_images[classes[i]].append(X_test[y])
X_test_images=[X_test_images[i]  for i in X_test_images]

# %%
columns = 10
fig,axes=plt.subplots(int(len(X_test_images)*len(X_test_images[0])/columns),columns,figsize=(40,20))
fig.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.4)
for i,ind in enumerate(X_test_images):
    #print(images_class)
    fig.suptitle('80 test dataset images and their own predicted class',fontsize=47)
    for j, image in enumerate(ind):
        print(j,image)
        if int((i)*(len(ind)/columns)+(int(j/columns)))<n_classes*(z_max/columns):
            axes[int((i)*(len(ind)/columns)+(int(j/columns))),j % columns].imshow(image)
            axes[int((i)*(len(ind)/columns)+(int(j/columns))),j % columns].set_title(f'{classes[i]}',pad=10)
#plt.savefig(os.path.join('plots/','80ValidationDatasetimages_and_predictedclass.png'), dpi=300)
#plt.savefig(os.path.join('plots/','80ValidationDatasetimages_and_predictedclass_white.png'), dpi=300,facecolor='w')

# %%
X_test.shape
# Out:
# (490, 160, 160, 3)
